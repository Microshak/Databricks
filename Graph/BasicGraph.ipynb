# %% [markdown]
# ## Overview
#
# This notebook will show you how to create and query a table or DataFrame that you uploaded to DBFS. [DBFS](https://docs.databricks.com/user-guide/dbfs-databricks-file-system.html) is a Databricks File System that allows you to store data for querying inside of Databricks. This notebook assumes that you have a file already inside of DBFS that you would like to read from.
#
# This notebook is written in **Python** so the default cell type is Python. However, you can use different languages by using the `%LANGUAGE` syntax. Python, Scala, SQL, and R are all supported.

# %%
# File location and type
from pyspark.sql.types import *
from pyspark.sql.functions import col, udf
from datetime import datetime

file_location = "/FileStore/tables/hubway_trips.csv"
file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "true"
delimiter = ","


#del df
# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", "true") \
  .option("dateFormat", "MM/dd/yyyy HH:mm:ss") \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

func =  udf (lambda x: datetime.strptime(x, '%m/%d/%Y %H:%M:%S'), DateType())

tripEdges = df.withColumn('start_date', func(col('start_date'))).withColumn('end_date', func(col('end_date'))).withColumnRenamed('strt_statn','src').withColumnRenamed('end_statn','dst')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
tripEdges.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- seq_id: integer (nullable = true)
# -- hubway_id: integer (nullable = true)
# -- status: string (nullable = true)
# -- duration: integer (nullable = true)
# -- start_date: date (nullable = true)
# -- src: integer (nullable = true)
# -- end_date: date (nullable = true)
# -- dst: integer (nullable = true)
# -- bike_nr: string (nullable = true)
# -- subsc_type: string (nullable = true)
# -- zip_code: string (nullable = true)
# -- birth_date: integer (nullable = true)
# -- gender: string (nullable = true)
#
# </div>

# %%
file_location = "/FileStore/tables/hubway_stations.csv"


# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","


#del df
# The applied options are for CSV files. For other file types, these will be ignored.
stationVerticies = spark.read.format(file_type) \
  .option("inferSchema", "true") \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#distance https://medium.com/@nikolasbielski/using-a-custom-udf-in-pyspark-to-compute-haversine-distances-d877b77b4b18
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
stationVerticies.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- id: integer (nullable = true)
# -- terminal: string (nullable = true)
# -- station: string (nullable = true)
# -- municipal: string (nullable = true)
# -- lat: double (nullable = true)
# -- lng: double (nullable = true)
# -- status: string (nullable = true)
#
# </div>

# %%
# Create a view or table

temp_table_name = "hubway_trips_csv"

df.createOrReplaceTempView(temp_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
small = spark.sql('select count(*) from hubway_trips_csv ')
display(small)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>1579025</td></tr></tbody></table></div>

# %% [markdown]
# ## Installs
# You need to install
#
# pip install graphframes
#
#
# and the Graph Jar that corresponds to your spark instance https://spark-packages.org/package/graphframes/graphframes

# %%
from functools import reduce
from pyspark.sql.functions import col, lit, when
from graphframes import *

stationGraph = GraphFrame(stationVerticies, tripEdges)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(stationGraph)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">GraphFrame(v:[id: int, terminal: string ... 5 more fields], e:[src: int, dst: int ... 11 more fields])
# </div>

# %% [markdown]
# # Basic graph and DataFrame queries
# GraphFrames provide several simple graph queries, such as node degree.

# %%
display(stationGraph.vertices)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>terminal</th><th>station</th><th>municipal</th><th>lat</th><th>lng</th><th>status</th></tr></thead><tbody><tr><td>3</td><td>B32006</td><td>Colleges of the Fenway</td><td>Boston</td><td>42.340021</td><td>-71.100812</td><td>Existing</td></tr><tr><td>4</td><td>C32000</td><td>Tremont St. at Berkeley St.</td><td>Boston</td><td>42.345392</td><td>-71.069616</td><td>Existing</td></tr><tr><td>5</td><td>B32012</td><td>Northeastern U / North Parking Lot</td><td>Boston</td><td>42.341814</td><td>-71.090179</td><td>Existing</td></tr><tr><td>6</td><td>D32000</td><td>Cambridge St. at Joy St.</td><td>Boston</td><td>42.361285</td><td>-71.06514</td><td>Existing</td></tr><tr><td>7</td><td>A32000</td><td>Fan Pier</td><td>Boston</td><td>42.353412</td><td>-71.044624</td><td>Existing</td></tr><tr><td>8</td><td>A32001</td><td>Union Square - Brighton Ave. at Cambridge St.</td><td>Boston</td><td>42.353334</td
458</td></tr><tr><td>29</td><td>4815</td></tr><tr><td>21</td><td>25551</td></tr><tr><td>98</td><td>11906</td></tr><tr><td>32</td><td>20432</td></tr><tr><td>60</td><td>13571</td></tr><tr><td>90</td><td>8926</td></tr><tr><td>75</td><td>20853</td></tr><tr><td>141</td><td>1775</td></tr><tr><td>145</td><td>221</td></tr><tr><td>56</td><td>2221</td></tr><tr><td>109</td><td>49</td></tr><tr><td>105</td><td>643</td></tr><tr><td>58</td><td>28285</td></tr><tr><td>33</td><td>31077</td></tr><tr><td>11< ...

# %%
# Run simple data frame queries
youngest = stationGraph.edges.groupBy().min("birth_date")
display(youngest)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>min(birth_date)</th></tr></thead><tbody><tr><td>1932</td></tr></tbody></table></div>

# %% [markdown]
# # Motifs

# %%
motifs = stationGraph.find("(a)-[e]->(b); (b)-[e2]->(a)")
display(motifs)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>a</th><th>e</th><th>b</th><th>e2</th></tr></thead><tbody><tr><td>List(22, A32010, South Station - 700 Atlantic Ave., Boston, 42.352175, -71.055547, Existing)</td><td>List(2731, 3008, Closed, 1933, 2011-07-31, 22, 2011-07-31, 3, B00533, Casual, null, null, null)</td><td>List(3, B32006, Colleges of the Fenway, Boston, 42.340021, -71.100812, Existing)</td><td>List(264, 308, Closed, 1955, 2011-07-28, 3, 2011-07-28, 22, B00071, Registered, '02118, 1967, Male)</td></tr><tr><td>List(22, A32010, South Station - 700 Atlantic Ave., Boston, 42.352175, -71.055547, Existing)</td><td>List(2731, 3008, Closed, 1933, 2011-07-31, 22, 2011-07-31, 3, B00533, Casual, null, null, null)</td><td>List(3, B32006, Colleges of the Fenway, Boston, 42.340021, -71.100812, Existing)</td><td>List(10009, 10981, Closed, 1553, 2011-08-07, 3, 2011-08-07, 22, B00251, Registered, '02115, 1980, Female)</td></tr><tr><td>List(22, A32010, South Station - 700 Atlantic Ave., Boston, 42.352175, -71.055547, Existing)</td><td>List(2731, 3008, Closed, 1933, 2011-07-31, 22, 2011-07-31, 3, B00533, Casual, null, null, null)</td><td>List(3, B32006, Colleges of the Fenway, Boston, 42.340021, -71.100812, Existing)</td><td>List(14157, 15523, Closed, 1278, 2011-08-11, 3, 2011-08-11, 22, B00177, Registered, '02118, 1977, Female)</td></tr><tr><td>List(22, A32010, South Station - 700 Atlantic Ave., Boston, 42.352175, -71.055547, Existing)</td><td>List(2731, 3008, Closed, 1933, 2011-07-31, 22, 2011-07-31, 3, B00533, Casual, null, null, null)</td><td>List(3, B32006, Colleges of the Fenway, Boston, 42.340021, -71.100812, Existing)</td><td>List(53064, 60700, Closed, 1493, 2011-09-12, 3, 2011-09-12, 22, B00050, Registered, '02113, 1986, Female)</td></tr><tr><td>List(22, A32010, South Station - 700 Atlantic Ave., Boston, 42.352175, -71.055547, Existing)</td><td>List(2731, 3008, Closed, 1933, 2011-07-31, 22, 2011-07-31, 3, B00533, Casual, null, null, null)</td><td>List(3, B32006, Colleges of the Fenway, Boston, 42.340021, -71.100812, Existing)</td><td>List(145028, 163299, Closed, 1109, 2012-03-21, 3, 2012-03-21, 22, B00404, Registered, '02360, 1961, Female)</td></tr><tr><td>List(22, A32010, South Station - 700 Atlantic Ave., Boston, 42.352175, -71.055547, Existing)</td><td>List(2731, 3008, Closed, 1933, 2011-07-31, 22, 2011-07-31, 3, B00533, Casual, null, null, null)</td><td>List(3, B32006, Colleges of the Fenway, Boston, 42.340021, -71.100812, Existing)</td><td>List(147860, 166839, Closed, 1269, 2012-03-23, 3, 2012-03-23, 22, B00531, Registered, '02360, 1961, Female)</td></tr><tr><td>List(22, A32010, South Station - 700 Atlantic Ave., Boston, 42.352175, -71.055547, Existing)</td><td>List(2731, 3008, Closed, 1933, 2011-07-31, 22, 2011-07-31, 3, B00533, Casual, null, null, null)</td><td>List(3, B32006, Colleges of the Fenway, Boston, 42.340021, -71.100812, Existing)</td><td>List(154029, 174250, Closed, 1058, 2012-03-30, 3, 2012-03-30, 22, B00012, Registered, '02360, 1961, Female)</td></tr><tr><td>List(22, A32010, South Station - 700 Atlantic Ave., Boston, 42.352175, -71.055547, Existing)</td><td>List(2731, 3008, Closed, 1933, 2011-07-31, 22, 2011-07-31, 3, B00533, Casual, null, null, null)</td><td>List(3, B32006, Colleges of the Fenway, Boston, 42.340021, -71.100812, Existing)</td><td>List(156465, 177203, Closed, 1142, 2012-04-02, 3, 2012-04-02, 22, B00192, Registered, '02360, 1961, Female)</td></tr><tr><td>List(22, A32010, South Station - 700 Atlantic Ave., Boston, 42.352175, -71.055547, Existing)</td><td>List(2731, 3008, Closed, 1933, 2011-07-31, 22, 2011-07-31, 3, B00533, Casual, null, null, null)</td><td>List(3, B32006, Colleges of the Fenway, Boston, 42.340021, -71.100812, Existing)</td><td>List(158966, 180154, Closed, 1417, 2012-04-04, 3, 2012-04-04, 22, B00309, Registered, '02045, 1970, Male)</td></tr><tr><td>List(22, A32010, South Station - 700 Atlantic Ave., Boston, 4 ...

# %%
filtered = motifs.filter("e.duration > 2000")
display(filtered)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-780692481473072&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>filtered <span class="ansiyellow">=</span> motifs<span class="ansiyellow">.</span>filter<span class="ansiyellow">(</span><span class="ansiblue">&quot;e.duration &gt; 2000&quot;</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      2</span> display<span class="ansiyellow">(</span>filtered<span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;motifs&apos; is not defined</div>

# %% [markdown]
# # Subgraphs
# GraphFrames provides APIs for building subgraphs by filtering on edges and vertices.

# %%
oldBoston = stationGraph.filterEdges("birth_date < '1940'").filterVertices("municipal = 'Boston'").dropIsolatedVertices()
display(oldBoston.vertices)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th
td><td>Registered</td><td>'02118</td><td>1938</td><td>Male</td></tr><tr><td>39960</td><td>46073</td><td>Closed</td><td>431</td><td>2011-09-02</td><td>46</td><td>2011-09-02</td><td>16</td><td>B00195</td><td>Registered</td><td>'02118</td><td>1938</td><td>Male</td></tr><tr><td>40020</td><td>46143</td><td>Closed</td><td>840</td><td>2011-09-02</td><td>36</td><td>2011-09-02</td><td>25</td><td>B00454</td><td>Registered</td><td>'02118</td><td>1938</td><td>Male</td></tr><tr><td>40074</td><td>46201</td><td>Closed</td><td>1431</td><td>2011-09-02</td><td>25</td><td>2011-09-02</td><td>25</td><td>B00454</td><td>Registered</td><td>'02118</td><td>1938</td><td>Male</td></tr><tr><td>48244</td><td>55318</td><td>Closed</td><td>610</td><td>2011-09-09</td><td>38</td><td>2011-09-09</td><td>47</td><td>B00068</td><td>Registered</td><td>'36301</td><td>1932</td><td>Female</td></tr><tr><td>49460</td><td>56677</td><td>Closed</td><td>1710</td><td>2011-09-10</td><td>38</td><td>2011-09-10</td><td>42</td><td>B00398</td><td>Registered</td><td>'36301</td><td>1932</td><td>Female</td></tr><tr><td>49729</td><td>56977</td><td>Closed</td><td>597</td><td>2011-09-10</td><td>48</td><td>2011-09-10</td><td>47</td><td>B00124</td><td>Registered</td><td>'36301</td><td>1932</td><td>Female</td></tr><tr><td>51641</td><td>59137</td><td>Closed</td><td>717</td><td>2011-09-11</td><td>38</td><td>2011-09-11</td><td>40</td><td>B00167</td><td>Registered</td><td>'36301</td><td>1932</td><td>Female</td></tr><tr><td>52565</td><td>60151</td><td>Closed</td><td>667</td><t ...

# %% [markdown]
# # Standard graph algorithms
# GraphFrames comes with a number of standard graph algorithms built in:
#
# * PageRank (regular and personalized)
# * Breadth-first search (BFS)
# * Connected components
# * Strongly connected components
# * Label Propagation Algorithm (LPA)
# * Shortest paths
# * Triangle count

# %% [markdown]
# #Breadth First Search

# %%
filteredPaths =stationGraph.bfs(
  fromExpr = "station = 'Seaport Hotel'",
  toExpr = "station == 'Mayor Thomas M. Menino - Government Center'",
  edgeFilter = "birth_date < 1960",
  maxPathLength = 1)
display(filteredPaths)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>from</th><th>e0</th><th>to</th></tr></thead><tbody><tr><td>List(31, B32014, Seaport Hotel, Boston, 42.348833, -71.041747, Existing)</td><td>List(5194, 5677, Closed, 251, 2011-08-04, 31, 2011-08-04, 23, B00061, Registered, '01810, 1957, Male)</td><td>List(23, B32008, Mayor Thomas M. Menino - Government Center, Boston, 42.359677, -71.059364, Removed)</td></tr><tr><td>List(31, B32014, Seaport Hotel, Boston, 42.348833, -71.041747, Existing)</td><td>List(23826, 26339, Closed, 284, 2011-08-19, 31, 2011-08-19, 23, B00424, Registered, '02110, 1955, Male)</td><td>List(23, B32008, Mayor Thomas M. Menino - Government Center, Boston, 42.359677, -71.059364, Removed)</td></tr><tr><td>List(31, B32014, Seaport Hotel, Boston, 42.348833, -71.041747, Existing)</td><td>List(136829, 153692, Closed, 307, 2011-11-22, 31, 2011-11-22, 23, B00361, Registered, '02116, 1950, Male)</td><td>List(23, B32008, Mayor Thomas M. Menino - Government Center, Boston, 42.359677, -71.059364, Removed)</td></tr><tr><td>List(31, B32014, Seaport Hotel, Boston, 42.348833, -71.041747, Existing)</td><td>List(233349, 267265, Closed, 688, 2012-05-22, 31, 2012-05-22, 23, B00412, Registered, '02446, 1955, Male)</td><td>List(23, B32008, Mayor Thomas M. Menino - Government Center, Boston, 42.359677, -71.059364, Removed)</td></tr><tr><td>List(31, B32014, Seaport Hotel, Boston, 42.348833, -71.041747, Existing)</td><td>List(259856, 297215, Closed, 688, 2012-06-06, 31, 2012-06-06, 23, B00104, Registered, '02130, 1954, Male)</td><td>List(23, B32008, Mayor Thomas M. Menino - Government Center, Boston, 42.359677, -71.059364, Removed)</td></tr><tr><td>List(31, B32014, Seaport Hotel, Boston, 42.348833, -71.041747, Existing)</td><td>List(316972, 360241, Closed, 1208, 2012-07-04, 31, 2012-07-04, 23, B00089, Registered, '01742, 1957, Female)</td><td>List(23, B32008, Mayor Thomas M. Menino - Government Center, Boston, 42.359677, -71.059364, Removed)</td></tr><tr><td>List(31, B32014, Seaport Hotel, Boston, 42.348833, -71.041747, Existing)</td><td>List(495651, 560120, Closed, 945, 2012-09-12, 31, 2012-09-12, 23, B00401, Registered, '02110, 1956, Male)</td><td>List(23, B32008, Mayor Thomas M. Menino - Government Center, Boston, 42.359677, -71.059364, Removed)</td></tr></tbody></table></div>

# %% [markdown]
# #Connected components

# %%
#sc.setCheckpointDir("/tmp/graphframes-connected-components")
result = stationGraph.connectedComponents()
display(result)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th
r><tr><td>20</td><td>B32004</td><td>Aquarium Station - 200 Atlantic Ave.</td><td>Boston</td><td>42.35977</td><td>-71.051601</td><td>Existing</td><td>3</td></tr><tr><td>21</td><td>C32007</td><td>Prudential Center / Belvidere</td><td>Boston</td><td>42.345959</td><td>-71.082578</td><td>Existing</td><td>3</td></tr><tr><td>22</td><td>A32010</td><td>South Station - 700 Atlantic Ave.</td><td>Boston</td><td>42.352175</td><td>-71.055547</td><td>Existing</td><td>3</td></tr><tr><td>23</td><td>B32008</td><td>Mayor Thomas M. Menino - Government Center</td><td>Boston</td><td>42.359677</td><td>-71.059364</td><td>Removed</td><td>3</td></tr><tr><td>24</td><td>B32007</td><td>Seaport Square - Seaport Blvd. at Boston Wharf</td><td>Boston</td><td>42.351821</td><td>-71.045461</td><td>Existing</td><td>3</td></tr><tr><td>25</td><td>A32009</td><td>Tremont St / W Newton St</td><td>Boston</td><td>42.341332</td><td>-71.076847</td><td>Existing</td><td>3</td></tr><tr><td>26</td><td>D32002</td><td>Washington St. at Waltham St.</td><td>Boston</td><td>42.341522</td><td>-71.068922</td><td>Existing</td><td>3< ...

# %% [markdown]
# # Conected Components
#
# In the below example we examine if all nodes are connected

# %%
cc = result.select('component').distinct()
display(cc)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>component</th></tr></thead><tbody><tr><td>3</td></tr></tbody></table></div>

# %% [markdown]
# # Label Propagation
# Run static Label Propagation Algorithm for detecting communities in networks.
#
# Each node in the network is initially assigned to its own community. At every superstep, nodes send their community affiliation to all neighbors and update their state to the most frequent community affiliation of incoming messages.
#
# LPA is a standard community detection algorithm for graphs. It is very inexpensive computationally, although (1) convergence is not guaranteed and (2) one can end up with trivial solutions (all nodes are identified into a single community).

# %%
vertices = sqlContext.createDataFrame([
  ("a", "Alice", 34),
  ("b", "Bob", 36),
  ("c", "Charlie", 30),
  ("d", "David", 29),
  ("e", "Esther", 32),
  ("f", "Fanny", 36),
  ("g", "Gabby", 60)], ["id", "name", "age"])
edges = sqlContext.createDataFrame([
  ("a", "b", "friend"),
  ("b", "c", "follow"),
  ("c", "b", "follow"),
  ("f", "c", "follow"),
  ("e", "f", "follow"),
  ("e", "d", "friend"),
  ("d", "a", "friend"),
  ("a", "e", "friend")
], ["src", "dst", "relationship"])

g = GraphFrame(vertices, edges)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
result = g.labelPropagation(maxIter=5)
display(result)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th><th>label</th></tr></thead><tbody><tr><td>g</td><td>Gabby</td><td>60</td><td>146028888064</td></tr><tr><td>b</td><td>Bob</td><td>36</td><td>1047972020224</td></tr><tr><td>e</td><td>Esther</td><td>32</td><td>412316860416</td></tr><tr><td>a</td><td>Alice</td><td>34</td><td>670014898176</td></tr><tr><td>f</td><td>Fanny</td><td>36</td><td>670014898176</td></tr><tr><td>d</td><td>David</td><td>29</td><td>670014898176</td></tr><tr><td>c</td><td>Charlie</td><td>30</td><td>1382979469312</td></tr></tbody></table></div>

# %% [markdown]
# Strongly connected components

# %%
result = g.stronglyConnectedComponents(maxIter=10)
display(result.select("id", "component"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>component</th></tr></thead><tbody><tr><td>g</td><td>146028888064</td></tr><tr><td>b</td><td>1047972020224</td></tr><tr><td>e</td><td>670014898176</td></tr><tr><td>a</td><td>670014898176</td></tr><tr><td>f</td><td>412316860416</td></tr><tr><td>d</td><td>670014898176</td></tr><tr><td>c</td><td>1047972020224</td></tr></tbody></table></div>

# %% [markdown]
# #PageRank
# Identify important vertices in a graph based on connections.

# %%
results = g.pageRank(resetProbability=0.15, tol=0.01)
display(results.vertices)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th><th>pagerank</th></tr></thead><tbody><tr><td>g</td><td>Gabby</td><td>60</td><td>0.1799821386239711</td></tr><tr><td>b</td><td>Bob</td><td>36</td><td>2.655507832863289</td></tr><tr><td>e</td><td>Esther</td><td>32</td><td>0.37085233187676075</td></tr><tr><td>a</td><td>Alice</td><td>34</td><td>0.44910633706538744</td></tr><tr><td>f</td><td>Fanny</td><td>36</td><td>0.3283606792049851</td></tr><tr><td>d</td><td>David</td><td>29</td><td>0.3283606792049851</td></tr><tr><td>c</td><td>Charlie</td><td>30</td><td>2.6878300011606218</td></tr></tbody></table></div>

# %%
display(results.edges)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>src</th><th>dst</th><th>relationship</th><th>weight</th></tr></thead><tbody><tr><td>a</td><td>b</td><td>friend</td><td>0.5</td></tr><tr><td>b</td><td>c</td><td>follow</td><td>1.0</td></tr><tr><td>e</td><td>f</td><td>follow</td><td>0.5</td></tr><tr><td>e</td><td>d</td><td>friend</td><td>0.5</td></tr><tr><td>c</td><td>b</td><td>follow</td><td>1.0</td></tr><tr><td>a</td><td>e</td><td>friend</td><td>0.5</td></tr><tr><td>f</td><td>c</td><td>follow</td><td>1.0</td></tr><tr><td>d</td><td>a</td><td>friend</td><td>1.0</td></tr></tbody></table></div>

# %% [markdown]
# # Shortest paths
# Computes shortest paths to the given set of landmark vertices, where landmarks are specified by vertex ID.

# %%
results = g.shortestPaths(landmarks=["a", "d"])
display(results)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th><th>distances</th></tr></thead><tbody><tr><td>g</td><td>Gabby</td><td>60</td><td>Map()</td></tr><tr><td>b</td><td>Bob</td><td>36</td><td>Map()</td></tr><tr><td>e</td><td>Esther</td><td>32</td><td>Map(d -> 1, a -> 2)</td></tr><tr><td>a</td><td>Alice</td><td>34</td><td>Map(a -> 0, d -> 2)</td></tr><tr><td>f</td><td>Fanny</td><td>36</td><td>Map()</td></tr><tr><td>d</td><td>David</td><td>29</td><td>Map(d -> 0, a -> 1)</td></tr><tr><td>c</td><td>Charlie</td><td>30</td><td>Map()</td></tr></tbody></table></div>

# %% [markdown]
# # Triangle count
# Computes the number of triangles passing through each vertex.

# %%
results = g.triangleCount()
display(results)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count</th><th>id</th><th>name</th><th>age</th></tr></thead><tbody><tr><td>0</td><td>g</td><td>Gabby</td><td>60</td></tr><tr><td>0</td><td>f</td><td>Fanny</td><td>36</td></tr><tr><td>1</td><td>e</td><td>Esther</td><td>32</td></tr><tr><td>1</td><td>d</td><td>David</td><td>29</td></tr><tr><td>0</td><td>c</td><td>Charlie</td><td>30</td></tr><tr><td>0</td><td>b</td><td>Bob</td><td>36</td></tr><tr><td>1</td><td>a</td><td>Alice</td><td>34</td></tr></tbody></table></div>
